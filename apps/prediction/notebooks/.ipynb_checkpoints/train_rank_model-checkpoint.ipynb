# %% [markdown]
# # JRDBデータを使用したランキング学習モデル
#
# 年度パックNPZファイルからデータを読み込み、LambdaRankモデルを学習します。

# %% [markdown]
# ## インポート

# %%
import sys
from pathlib import Path
import importlib

# プロジェクトルート（apps/prediction/）をパスに追加
project_root = Path().resolve().parent  # notebooks/ -> apps/prediction/
sys.path.insert(0, str(project_root))

# autoreloadを先に設定（これにより、以降のインポートが自動リロード対象になる）
# %reload_ext autoreload
# %autoreload 2

# 既にインポート済みのモジュールを明示的にリロード（初回実行時）
if 'src.preprocessor' in sys.modules:
    importlib.reload(sys.modules['src.preprocessor'])
if 'src.data_loader' in sys.modules:
    importlib.reload(sys.modules['src.data_loader'])
if 'src.rank_predictor' in sys.modules:
    importlib.reload(sys.modules['src.rank_predictor'])
if 'src.features' in sys.modules:
    importlib.reload(sys.modules['src.features'])
if 'src.feature_converter' in sys.modules:
    importlib.reload(sys.modules['src.feature_converter'])

import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_annual_pack_npz, load_multiple_npz_files
from src.preprocessor import Preprocessor
from src.rank_predictor import RankPredictor
from src.features import Features
from src.feature_converter import FeatureConverter

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 15
#      13 # 既にインポート済みのモジュールを明示的にリロード（初回実行時）
#      14 if 'src.preprocessor' in sys.modules:
# ---> 15     importlib.reload(sys.modules['src.preprocessor'])
#      16 if 'src.data_loader' in sys.modules:
#      17     importlib.reload(sys.modules['src.data_loader'])
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:169, in reload(module)
#     167 if spec is None:
#     168     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169 _bootstrap._exec(spec, module)
#     170 # The module may have replaced itself in sys.modules!
#     171 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:613, in _exec(spec, module)
#
# ...

# %% [markdown]
# ## 設定

# %%
# NPZファイルが格納されているベースパス
# ノートブックと同じディレクトリのdataフォルダにNPZファイルを配置
BASE_PATH = Path('./data')  # apps/prediction/notebooks/data

# 使用するデータタイプ
# レース開始時点で利用可能なデータのみを含める
# オッズデータ（OZ, OW, OU, OT, OV）と払戻データ（HJC, HJB）は除外
DATA_TYPES = [
    'BAC',  # 番組データ（レース条件・出走馬一覧）
    'KYI',  # 競走馬データ（牧場先情報付き・最も詳細）
    'SED',  # 成績速報データ（過去の成績・前走データ抽出に使用）
    'UKC',  # 馬基本データ（血統登録番号・性別・生年月日・血統情報）
    'TYB',  # 直前情報データ（出走直前の馬の状態・当日予想に最重要）
    # 以下は年度パックがないため、現時点では除外
    # 'KKA',  # 競走馬拡張データ（KY系の詳細情報・年度パックなし・予測モデルでは直接使用されていない）
    # 'JOA',  # 情報データ（詳細情報による予想精度向上・年度パックなし・予測モデルでは直接使用されていない）
    # マスターデータ（使用しない）
    # 'KZA',  # 騎手データ（全騎手分・勝率・連対率）
    # 'CZA',  # 調教師データ（全調教師分・勝率・連対率）
    # 注意: マスターデータには最新の統計情報が含まれるため、未来の情報が混入する可能性がある
    # 代わりに、SEDデータから時系列で統計量を計算（add_statistical_features）を使用
]

# 使用する年度
YEARS = [2024]  # 必要に応じて複数年度を指定

# モデル保存パス
MODEL_PATH = Path('../models/rank_model_v1.txt')
MODEL_PATH.parent.mkdir(parents=True, exist_ok=True)

# ファイル名の確認（デバッグ用）
print(f"BASE_PATH: {BASE_PATH.absolute()}")
if BASE_PATH.exists():
    npz_files = list(BASE_PATH.glob('*.npz'))
    print(f"見つかったNPZファイル: {len(npz_files)}件")
    for f in npz_files[:5]:  # 最初の5件を表示
        print(f"  - {f.name}")
else:
    print(f"警告: {BASE_PATH} が存在しません")
# Out:
# BASE_PATH: /Users/soichiro/Dev/umayomi/apps/prediction/notebooks/data
# 見つかったNPZファイル: 10件
#   - jrdb_npz_SEC_2024.npz
#   - jrdb_npz_UKC_2024.npz
#   - jrdb_npz_KYH_2024.npz
#   - jrdb_npz_KYI_2024.npz
#   - jrdb_npz_SED_2024.npz

# %% [markdown]
# ## データ読み込みと前処理

# %%
# 前処理を実行
preprocessor = Preprocessor()

print("データ読み込みと前処理を開始します...")
try:
    df = preprocessor.process(
        base_path=BASE_PATH,
        data_types=DATA_TYPES,
        years=YEARS,
        use_annual_pack=True
    )

    print(f"\nデータ読み込み完了: {len(df)}件")
    print(f"レース数: {df.index.nunique()}")
    print(f"\nデータ形状: {df.shape}")
    print(f"\n列名: {df.columns.tolist()[:20]}...")  # 最初の20列を表示
    
    # rankフィールドの確認
    if 'rank' in df.columns:
        print(f"\nrankフィールド: あり（欠損値: {df['rank'].isnull().sum()}件）")
        print(f"着順の分布: {df['rank'].value_counts().sort_index()}")
    else:
        print("\n警告: rankフィールドが見つかりません")
        
except Exception as e:
    print(f"エラーが発生しました: {e}")
    import traceback
    traceback.print_exc()
    raise
# Out:
# データ読み込みと前処理を開始します...
# 前処理済みデータを読み込みました: data/preprocessed_data/BAC_KYI_SED_TYB_UKC_2024_annual_data.npz
#   データ数: 261930件
#   特徴量数: 357件
#
# データ読み込み完了: 261930件
# レース数: 3454
#
# データ形状: (261930, 357)
#
# 列名: ['LS指数順位', 'R', 'クラスコード', 'ゴール内外', 'ゴール差', 'ゴール順位', 'ダ適性コード', 'テン指数', 'テン指数順位', 'フラグ', 'ブリンカー', 'ペース予想', 'ペース指数', 'ペース指数順位', 'ローテーション', '万券印', '万券指数', '上がり指数', '上がり指数順位', '上昇度']...
#
# rankフィールド: あり（欠損値: 1981件）
# 着順の分布: rank
# 1.0     19632
# 2.0     21847
# 3.0     21655
# 4.0     21715
# 5.0     21398
# 6.0     20387
# 7.0     19736
# 8.0     18904
# 9.0     17673
# 10.0    16137
# 11.0    14351
# 12.0    12695
# 13.0    10794
# 14.0     9091
# 15.0     7099
# 16.0     4775
# 17.0     1232
# 18.0      828
# Name: count, dtype: int64

# %% [markdown]
# ## データ確認

# %%
# データの基本統計
print("基本統計:")
print(df.describe())

# 欠損値の確認
print("\n欠損値:")
print(df.isnull().sum().sort_values(ascending=False).head(20))

# 着順の分布
if 'rank' in df.columns:
    print("\n着順の分布:")
    print(df['rank'].value_counts().sort_index())

# データの上位50件を表示（すべての列を表示）
print("\n" + "=" * 60)
print("データの上位50件:")
print("=" * 60)
# すべての列を表示するためのオプション設定
df.head(10)
# Out:
# 基本統計:
#               LS指数順位              R         クラスコード          ゴール内外  \
# count  261930.000000  261930.000000  261930.000000  261930.000000
# mean        4.055339       6.867759      23.886833       2.541045
# std         1.630971       3.471946      13.387428       1.327548
# min         0.000000       1.000000       0.000000       0.000000
# 25%         3.000000       4.000000      15.000000       1.000000
# 50%         5.000000       7.000000      18.000000       2.000000
# 75%         5.000000      10.000000      35.000000       4.000000
# max         9.000000      12.000000      62.000000       5.000000
#
#                 ゴール差          ゴール順位         テン指数順位        ペース指数順位  \
# count  261930.000000  261930.000000  261930.000000  261930.000000
# mean       11.502073       7.077879       7.253755       7.140751
# std         8.999323       4.375469       4.423791       4.391358
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ## 学習・検証データの分割

# %%
# 学習・検証データに分割（レース単位で時系列分割）
train_df, val_df = preprocessor.split(df, train_ratio=0.8)

print(f"学習データ: {len(train_df)}件 ({len(train_df.index.unique())}レース)")
print(f"検証データ: {len(val_df)}件 ({len(val_df.index.unique())}レース)")

# 着順の分布を確認
if 'rank' in train_df.columns:
    print("\n学習データの着順分布:")
    print(train_df['rank'].value_counts().sort_index())
    
    print("\n検証データの着順分布:")
    print(val_df['rank'].value_counts().sort_index())
# Out:
# 学習データ: 213654件 (2763レース)
# 検証データ: 48276件 (691レース)
#
# 学習データの着順分布:
# rank
# 1.0     16222
# 2.0     18174
# 3.0     18050
# 4.0     17967
# 5.0     17663
# 6.0     16824
# 7.0     16195
# 8.0     15492
# 9.0     14420
# 10.0    13077
# 11.0    11504
# 12.0    10057
# 13.0     8559
# 14.0     7183
# 15.0     5417
# 16.0     3596
# 17.0      971
# 18.0      654
# Name: count, dtype: int64
#
# 検証データの着順分布:
# rank
# 1.0     3410
# 2.0     3673
# 3.0     3605
# 4.0     3748
# 5.0     3735
# 6.0     3563
# 7.0     3541
# 8.0     3412
# 9.0     3253
# 10.0    3060
# 11.0    2847
# 12.0    2638
# 13.0    2235
# 14.0    1908
# 15.0    1682
# 16.0    1179
# 17.0     261
# 18.0     174
# Name: count, dtype: int64

# %% [markdown]
# ## モデル学習

# %%
# RankPredictorのインスタンスを作成
rank_predictor = RankPredictor(train_df, val_df)

print("モデル学習を開始します...")
print("（Optunaによるハイパーパラメータチューニングが実行されます）")
print("\n効率化設定（推奨度3まで実装済み）:")
print("  ✓ 早期停止: 50ラウンド（推奨度1: ★★★★★）")
print("  ✓ データ型最適化: 有効（推奨度2: ★★★★☆）")
print("  ✓ Optuna試行回数制限: 50回（推奨度3: ★★★☆☆）")
print("\n必要に応じて以下のパラメータを調整可能:")
print("  - early_stopping_rounds: 早期停止のラウンド数（デフォルト: 50）")
print("  - optuna_n_trials: Optunaの試行回数（デフォルト: 50）")
print("  - optuna_timeout: Optunaの最大実行時間（秒、デフォルト: None）")

# モデルを学習（推奨度3までの効率化が有効）
# 例: より多くの試行回数が必要な場合
# model = rank_predictor.train(optuna_n_trials=100)
model = rank_predictor.train()

print("\nモデル学習完了")
# Out:
# [I 2025-11-11 08:31:21,959] A new study created in memory with name: no-name-17bc3aad-29e1-4c45-93ab-23e1b14ed8ed
# モデル学習を開始します...
# （Optunaによるハイパーパラメータチューニングが実行されます）
#
# 効率化設定（推奨度3まで実装済み）:
#   ✓ 早期停止: 50ラウンド（推奨度1: ★★★★★）
#   ✓ データ型最適化: 有効（推奨度2: ★★★★☆）
#   ✓ Optuna試行回数制限: 50回（推奨度3: ★★★☆☆）
#
# 必要に応じて以下のパラメータを調整可能:
#   - early_stopping_rounds: 早期停止のラウンド数（デフォルト: 50）
#   - optuna_n_trials: Optunaの試行回数（デフォルト: 50）
#   - optuna_timeout: Optunaの最大実行時間（秒、デフォルト: None）
# ...
# min_child_samples, val_score: 0.411688: 100%|##########| 5/5 [00:05<00:00,  1.10s/it]
# 最適パラメータ: {'objective': 'lambdarank', 'metric': 'ndcg', 'ndcg_eval_at': [1, 2, 3], 'boosting_type': 'gbdt', 'random_state': 0, 'num_leaves': 6, 'deterministic': True, 'force_row_wise': True, 'num_threads': 12, 'max_bin': 255, 'verbose': -1, 'early_stopping_rounds': 50, 'feature_pre_filter': False, 'min_child_samples': 20, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'feature_fraction': 0.4, 'bagging_fraction': 0.628810338224914, 'bagging_freq': 4}
#
# ...

# %% [markdown]
# ## モデル保存

# %%
# モデルを保存
model.save_model(str(MODEL_PATH))
print(f"モデルを保存しました: {MODEL_PATH}")
# Out:
# モデルを保存しました: ../models/rank_model_v1.txt

# %%
# 検証データで予測を実行
print("検証データで予測を実行します...")
val_predictions_with_rank = RankPredictor.predict(model, val_df, rank_predictor.features)

print(f"予測完了: {len(val_predictions_with_rank)}件")
print(f"\n予測結果のサンプル:")
print(val_predictions_with_rank.head(10))

# 基本的な評価を実行（オッズなし）
print("\n" + "=" * 60)
print("モデル評価（オッズなし）:")
print("=" * 60)
RankPredictor.print_evaluation(val_predictions_with_rank)
# Out:
# 検証データで予測を実行します...
# 予測完了: 48276件
#
# 予測結果のサンプル:
#    predict             race_key  LS指数順位  R  クラスコード  ゴール内外  ゴール差  ゴール順位 ダ適性コード  \
# 0     0.26  20241019_08_05_5_02     5.0  2    18.0    2.0   0.0    2.0
# 1    -0.69  20241019_08_05_5_02     5.0  2    18.0    1.0   3.0    3.0
# 2     0.26  20241019_08_05_5_02     5.0  2    18.0    2.0   0.0    2.0
# 3     0.26  20241019_08_05_5_02     5.0  2    18.0    2.0   0.0    2.0
# 4     0.26  20241019_08_05_5_02     5.0  2    18.0    2.0   0.0    2.0
# 5     0.26  20241019_08_05_5_02     5.0  2    18.0    2.0   0.0    2.0
# 6    -0.69  20241019_08_05_5_02     5.0  2    18.0    1.0   3.0    3.0
# 7    -0.31  20241019_08_05_5_02     1.0  2    18.0    4.0  14.0    9.0
# 8    -0.97  20241019_08_05_5_02     5.0  2    18.0    1.0  48.0   10.0
# 9    -0.97  20241019_08_05_5_02     5.0  2    18.0    1.0  48.0   10.0
#
#     テン指数  テン指数順位     フラグ ブリンカー ペース予想  ペース指数  ペース指数順位  ローテーション 万券印  万券指数  \
# ...

# %% [markdown]
# ## モデル評価

# %%
# オッズデータがある場合の回収率計算
print("\n" + "=" * 60)
print("回収率計算")
print("=" * 60)

# まず、val_predictions_with_rankに既に'確定単勝オッズ'カラムが含まれているか確認
if '確定単勝オッズ' in val_predictions_with_rank.columns:
    print("val_predictions_with_rankに'確定単勝オッズ'カラムが既に含まれています")
    val_predictions_with_odds = val_predictions_with_rank.copy()
else:
    # preprocessorからオッズデータを取得してマージ
    odds_df = preprocessor.get_odds_data()
    
    if odds_df is None or len(odds_df) == 0:
        print("\n警告: preprocessorからオッズデータが取得できませんでした。")
        print("SEDデータから直接'確定単勝オッズ'を取得を試みます...")
        
        # SEDデータから直接取得を試みる
        try:
            # 元のデータからSEDデータを取得
            data_dict = preprocessor.load_and_combine_data(
                base_path=BASE_PATH,
                data_types=['SED'],
                years=YEARS,
                use_annual_pack=True
            )
            
            if 'SED' in data_dict and '確定単勝オッズ' in data_dict['SED'].columns:
                sed_df = data_dict['SED'].copy()
                
                # race_keyを生成
                if 'race_key' not in sed_df.columns:
                    bac_data_dict = preprocessor.load_and_combine_data(
                        base_path=BASE_PATH,
                        data_types=['BAC'],
                        years=YEARS,
                        use_annual_pack=True
                    )
                    bac_df = bac_data_dict.get('BAC')
                    if bac_df is not None:
                        sed_df = FeatureConverter.add_race_key_to_df(
                            sed_df, bac_df=bac_df, use_bac_date=True
                        )
                    else:
                        sed_df = FeatureConverter.add_race_key_to_df(sed_df, use_bac_date=False)
                
                # オッズデータを抽出
                if 'race_key' in sed_df.columns and '馬番' in sed_df.columns:
                    odds_df = sed_df[['race_key', '馬番', '確定単勝オッズ']].copy()
                    odds_df = odds_df[odds_df['race_key'].notna() & odds_df['馬番'].notna()].copy()
                    odds_df['race_key'] = odds_df['race_key'].astype(str)
                    odds_df['馬番'] = pd.to_numeric(odds_df['馬番'], errors='coerce')
                    print(f"SEDデータからオッズデータを取得: {len(odds_df)}件")
                else:
                    odds_df = None
            else:
                odds_df = None
        except Exception as e:
            print(f"SEDデータからの取得に失敗: {e}")
            import traceback
            traceback.print_exc()
            odds_df = None
    
    # val_predictions_with_oddsを初期化（odds_dfがNoneでも定義する）
    val_predictions_with_odds = val_predictions_with_rank.copy()
    
    if odds_df is None or len(odds_df) == 0:
        print("\n警告: オッズデータが取得できませんでした。回収率は計算されません。")
        print("（SEDデータに'確定単勝オッズ'カラムが存在しない可能性があります）")
    else:
        print(f"\nオッズデータ取得: {len(odds_df)}件")
        
        # インデックスがrace_keyの場合はリセット
        if val_predictions_with_odds.index.name == 'race_key':
            val_predictions_with_odds = val_predictions_with_odds.reset_index()
        
        # race_keyと馬番の型を統一
        val_predictions_with_odds['race_key'] = val_predictions_with_odds['race_key'].astype(str)
        val_predictions_with_odds['馬番'] = pd.to_numeric(val_predictions_with_odds['馬番'], errors='coerce')
        
        # オッズデータをマージ
        val_predictions_with_odds = val_predictions_with_odds.merge(
            odds_df,
            on=['race_key', '馬番'],
            how='left'
        )

# 確定単勝オッズカラムが存在するか確認
if '確定単勝オッズ' in val_predictions_with_odds.columns:
    # 確定単勝オッズを数値に変換
    def parse_odds(odds_val):
        if pd.isna(odds_val) or odds_val == '':
            return np.nan
        try:
            return float(str(odds_val).strip())
        except Exception:
            return np.nan
    
    val_predictions_with_odds['確定単勝オッズ'] = val_predictions_with_odds['確定単勝オッズ'].apply(parse_odds)
    
    # オッズデータがマージできたか確認
    odds_merged_count = val_predictions_with_odds['確定単勝オッズ'].notna().sum()
    print(f"\nオッズデータがマージできた件数: {odds_merged_count}/{len(val_predictions_with_odds)}")
    
    if odds_merged_count == 0:
        print("警告: オッズデータが1件もマージできませんでした。回収率は計算されません。")
    else:
        # 回収率を含む評価
        print("\n" + "=" * 60)
        print("モデル評価（回収率含む）:")
        print("=" * 60)
        RankPredictor.print_evaluation(val_predictions_with_odds, odds_col='確定単勝オッズ')
else:
    print("\n警告: '確定単勝オッズ'カラムが見つかりません。")
    print("（回収率は計算されません）")
# Out:
# 警告: オッズデータが取得できませんでした。回収率は計算されません。
# （SEDデータに'確定単勝オッズ'カラムが存在しない可能性があります）

# %% [markdown]
# ## 特徴量重要度

# %%
# 特徴量重要度を取得
importance = model.feature_importance(importance_type='gain')
feature_names = [f for f in rank_predictor.features.encoded_feature_names if f in val_df.columns]

importance_df = pd.DataFrame({
    'feature': feature_names[:len(importance)],
    'importance': importance
}).sort_values('importance', ascending=False)

print("特徴量重要度（上位20）:")
print(importance_df.head(20))

# 可視化
plt.figure(figsize=(10, 8))
sns.barplot(data=importance_df.head(20), y='feature', x='importance')
plt.title('特徴量重要度（上位20）')
plt.xlabel('重要度')
plt.tight_layout()
plt.show()
# Out:
# 特徴量重要度（上位20）:
#                     feature   importance
# 20              prev_1_rank  5343.675213
# 13                jockey_id  2173.532703
# 30              prev_2_rank  1405.107414
# 12                 horse_id   991.279982
# 40              prev_3_rank   643.139238
# 15               trainer_id   434.527248
# 14            jockey_weight   303.063290
# 50              prev_4_rank   268.742574
# 5                   prize_1   262.061999
# 4                num_horses   232.938139
# 31              prev_2_time   198.283600
# 6                   prize_2   185.457600
# 21              prev_1_time   155.466061
# 22          prev_1_distance   149.007196
# 61              prev_5_time   140.248733
# 42          prev_3_distance   104.109098
# 51              prev_4_time   101.614169
# 41              prev_3_time    98.936670
# 27        prev_2_num_horses    98.001439
# 25  prev_1_ground_condition    96.718650
# ...
